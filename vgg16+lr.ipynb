# %% [markdown]
# ## Install Packages

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install keras
# !pip install tensorflow
# !pip install SciPy
# !pip install sklearn
# !pip install scikit-learn
# !pip install opencv-python
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\5458\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\5458\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\5458\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: keras in c:\users\dell\anaconda3\envs\5458\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\envs\5458\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.0.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Requirement already satisfied: SciPy in c:\users\dell\anaconda3\envs\5458\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from SciPy) (1.23.5)
# Requirement already satisfied: sklearn in c:\users\dell\anaconda3\envs\5458\lib\site-packages (0.0.post1)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\envs\5458\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\envs\5458\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\envs\5458\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.0.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\anaconda3\envs\5458\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %% [markdown]
# ## Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg19 import VGG19,preprocess_input , decode_predictions
from keras.applications.vgg16 import VGG16,preprocess_input , decode_predictions
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import warnings
from keras.models import load_model
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
os.listdir("pneumonia/chest_xray/train")
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
train_datagen=ImageDataGenerator(zoom_range= 0.5,shear_range=0.3,horizontal_flip= True,preprocessing_function = preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function= preprocess_input)

# %%
train = train_datagen.flow_from_directory(directory= "pneumonia/chest_xray/train",target_size=(256,256),batch_size=32)
val = val_datagen.flow_from_directory(directory= "pneumonia/chest_xray/train",target_size=(256,256),batch_size=32)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 5216 images belonging to 2 classes.

# %%
t_img , label =train.next()

# %%
def plotImage(img_arr,label):
    for im , l in zip(img_arr , label):
        plt.figure(figsize=(5,5))
        plt.imshow(im/255)
        plt.show()

# %%
plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### iv) Using VGG-16 Feature Extractor + Logistic Regression

# %%
from keras.applications.vgg16 import VGG16,preprocess_input , decode_predictions

# %%
base_model=VGG16(input_shape=(256,256,3), include_top= False)

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.layers import Dense, Activation, Flatten
from tensorflow.keras.models import Model

# %%
X= Flatten()(base_model.output)

X= Dense(units= 2,activation= 'softmax')(X)

model= Model(base_model.input,X)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 2)                 65538
#
# =================================================================
# Total params: 14,780,226
# Trainable params: 65,538
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint , EarlyStopping
#early stopping
es = EarlyStopping(monitor = 'val_accuracy',min_delta=0.01,patience=3,verbose=1)
#model check point
mc = ModelCheckpoint(filepath="best_mmodel.h5",monitor='val_accuracy',min_delta= 0.01,patience=3,verbose=1,save_best_only=True)

cb=[es,mc]

# %%
model.compile(optimizer= 'adam',loss= keras.losses.categorical_crossentropy, metrics = ['accuracy'])

# %%
his = model.fit(train ,steps_per_epoch= 16,epochs = 5,verbose= 1,callbacks= cb,validation_data=val ,validation_steps = 16)
# Out:
# Epoch 1/5
# 16/16 [==============================] - ETA: 0s - loss: 5.2333 - accuracy: 0.7988
# Epoch 1: val_accuracy improved from -inf to 0.91016, saving model to best_mmodel.h5
# 16/16 [==============================] - 547s 35s/step - loss: 5.2333 - accuracy: 0.7988 - val_loss: 2.5887 - val_accuracy: 0.9102
# Epoch 2/5
# 16/16 [==============================] - ETA: 0s - loss: 2.0882 - accuracy: 0.8926
# Epoch 2: val_accuracy improved from 0.91016 to 0.93164, saving model to best_mmodel.h5
# 16/16 [==============================] - 569s 36s/step - loss: 2.0882 - accuracy: 0.8926 - val_loss: 2.6401 - val_accuracy: 0.9316
# Epoch 3/5
# 16/16 [==============================] - ETA: 0s - loss: 1.5472 - accuracy: 0.9316
# Epoch 3: val_accuracy did not improve from 0.93164
# 16/16 [==============================] - 534s 34s/step - loss: 1.5472 - accuracy: 0.9316 - val_loss: 2.0614 - val_accuracy: 0.9219
# Epoch 4/5
# 16/16 [==============================] - ETA: 0s - loss: 1.5358 - accuracy: 0.9199
# Epoch 4: val_accuracy improved from 0.93164 to 0.95117, saving model to best_mmodel.h5
# 16/16 [==============================] - 612s 39s/step - loss: 1.5358 - accuracy: 0.9199 - val_loss: 1.7813 - val_accuracy: 0.9512
# Epoch 5/5
# 16/16 [==============================] - ETA: 0s - loss: 2.0658 - accuracy: 0.9180
# Epoch 5: val_accuracy did not improve from 0.95117
# 16/16 [==============================] - 408s 26s/step - loss: 2.0658 - accuracy: 0.9180 - val_loss: 1.9304 - val_accuracy: 0.9375

# %%
classes={'NORMAL':0, 'PNEUMONIA':1}
X=[]
Y=[]
for cls in classes:
    pth="pneumonia/chest_xray/train/"+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

X=np.array(X)
Y=np.array(Y)

X_updated= X.reshape(len(X), -1)

xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, test_size=.20)

xtrain= xtrain/255
xtest= xtest/255

clf = LogisticRegression(random_state=0, tol=1e-5)
clf.fit(xtrain, ytrain)
predicted = clf.predict(xtest)
acc=accuracy_score(ytest, clf.predict(xtest))
print(acc)
cm=confusion_matrix(ytest, predicted, labels= clf.classes_)
cmdisp=ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["NORMAL", "PNEUMONIA"])
cmdisp.plot()
# Out:
# C:\Users\DELL\anaconda3\envs\5458\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.960727969348659

# %%
model.save("best_mmodel.h5")

# %%
model = load_model('best_mmodel.h5')
img = load_img('pneumonia/chest_xray/train/PNEUMONIA/person1_bacteria_1.jpeg', target_size=(256, 256))
i = img_to_array(img)
im = preprocess_input(i)
img = np.expand_dims(im,axis=0)
pred = np.argmax(model.predict(img))
print(pred)
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1

# %%
for k in train.class_indices.keys():
    if train.class_indices[k]==pred:
        print(k)
# Out:
# PNEUMONIA

# %%
h = his.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(8,6))
plt.title('Accuracy scores')
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['acc', 'val_acc'])
plt.show()
plt.figure(figsize=(8,6))
plt.title('Loss value')
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall: {0:0.2f}%'.format(recall))
print('F1-score: {0:0.2f}'.format(2*precision*recall/(precision+recall)))
# Out:
# Accuracy: 0.96%
# Precision: 96.92%
# Recall: 97.80%
# F1-score: 97.36

# %%
VGG16_ACC=acc*100
print(VGG16_ACC)
# Out:
# 96.0727969348659
